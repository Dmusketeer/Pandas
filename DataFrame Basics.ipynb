# %% [markdown]
# # <h1>Dheeraj</h1>
# ![pandas.png](attachment:pandas.png )

# %%
import pandas as pd

# %%
# dic={'Station ID': [8809, 8810, 8811, 8812, 8813],
#         'Pollutants': ['{"a": "46", "b": "3", "c": "12"}', '{"a": "36", "b": "5", "c": "8"}', '{"b": "2", "c": "7"}', '{"c": "11"}', '{"a": "82", "c": "15"}']}
# df= pd.DataFrame(dic)
# df

# %%
dat = pd.DataFrame({'month': [1, 4, 7, 10],
                   'year': [2012, 2014, 2013, 2014],
                   'sale': [55, 40, 84, 31]})
dat
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
df=pd.read_csv(r"C:\Users\DHEERAJ TIWARI\Desktop\salaries.csv")
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.shape
# Out:
# (78, 6)

# %%
rows,columns=df.shape

# %%
rows
# Out:
# 78

# %%
columns
# Out:
# 6

# %%
df.head()
# df.head(3) will print 3 rows
# df.tail()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df[2:5]
# Out:
#    rank discipline  phd  service   sex  salary
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
# df.phd
# or
df["phd"]
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
type(df["phd"])
# Out:
# pandas.core.series.Series

# %%
df[['rank','discipline','sex']]
# Out:
#          rank discipline     sex
# 0        Prof          B    Male
# 1        Prof          A    Male
# 2        Prof          A    Male
# 3        Prof          A    Male
# 4        Prof          B    Male
# ..        ...        ...     ...
# 73       Prof          B  Female
# 74  AssocProf          B  Female
# 75       Prof          B  Female
# 76       Prof          A  Female
# 77       Prof          A  Female
#
# [78 rows x 3 columns]

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df[df.salary>=150000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750
# 44  Prof          B   23       19  Female  151768
# 72  Prof          B   24       15  Female  161101

# %%
[df.salary>=df['salary'].max()]
# Out:
# [0      True
#  1     False
#  2     False
#  3     False
#  4     False
#        ...
#  73    False
#  74    False
#  75    False
#  76    False
#  77    False
#  Name: salary, Length: 78, dtype: bool]

# %%
df['sex'][df.salary>=df['salary'].max()]
# Out:
# 0    Male
# Name: sex, dtype: object

# %%
df.loc['Male']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\programs\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Male'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-80dcb47fde47> in <module>
# ----> 1 df.loc['Male']
#
# F:\programs\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
# ...
